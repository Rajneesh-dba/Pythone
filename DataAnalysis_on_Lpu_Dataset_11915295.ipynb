# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt
data=pd.read_csv("C:/Users/rajneesh/Desktop/11915295.csv")
CA_100=np.nan_to_num(data.CA_100)
CA_100_Mean=(statistics.mean(CA_100))
CA_100_Mode=(statistics.mode(data.CA_100))
CA_100_Median=(statistics.median(CA_100))

MTT_50=np.nan_to_num(data.MTT_50)
print()
MTT_50_Mode=(statistics.mode(data.MTT_50))
MTT_50_Mean=(statistics.mean(MTT_50))
MTT_50_Median=(statistics.median(MTT_50))

ETT_100=np.nan_to_num(data.ETT_100)
print()
ETT_100_Mean=(statistics.mean(ETT_100))
ETT_100_Mode=(statistics.mode(data.ETT_100))
ETT_100_Median=(statistics.median(data.ETT_100))

ETP_100=np.nan_to_num(data.ETP_100)
print()
ETP_100_Mean=(statistics.mean(ETP_100))
ETP_100_Mode=(statistics.mode(data.ETP_100))
ETP_100_Median=(statistics.median(data.ETP_100))

Course_Att=np.nan_to_num(data.Course_Att)
print()
Course_Att_Mean=(statistics.mean(Course_Att))
Course_Att_Mode=(statistics.mode(data.Course_Att))
Course_Att_Median=(statistics.median(data.Course_Att))


Height=np.nan_to_num(data.Height)
print()
Height_Mean=(statistics.mean(Height))
Height_Mode=(statistics.mode(data.Height))
Height_Median=(statistics.median(data.Height))

print(f"CA_100 average marks is {CA_100_Mean} and their median value is {CA_100_Median} and its mode Value is {CA_100_Mode}")

CA_100_Chunk=[CA_100_Mean,CA_100_Median,CA_100_Mode]
plt.hist(CA_100_Chunk)
MTT_50_Chunk=[MTT_50_Mean,MTT_50_Median,MTT_50_Mode]
plt.plot(CA_100_Chunk,MTT_50_Chunk,xlevel=CA_100_Marks)
plt.show()

# %%
plt.bar(CA_100_Chunk,MTT_50_Chunk)
label=['Mean','Median','Mode']
plt.plot(CA_100_Chunk,MTT_50_Chunk,lineStyle='--',Color='green',marker='o',markerFacecolor='red',markersize=10)
plt.title("DATA COMPARISION ON BASICE OF CA IS IMPORTANT THAN MTT ASUMPTION")
plt.show()

# %%
#B_tech_cse_dataScience Students
B_tech_cse_dataScience=data[data.MHRDName=="Bachelor of Technology in Computer Science and Engineering (Data Science)"]

#B_tech_cse_cyberSecurity Students
B_tech_cse_cyberSecurity=data[data.MHRDName=="Bachelor of Technology in Computer Science and Engineering (Cyber Security)"]

#Bachelor of Technology in Computer Science and Engineering (Android Application Development)
B_tech_cse_androidDevelopment=data[data.MHRDName=="Bachelor of Technology in Computer Science and Engineering (Android Application Development)"]

#B_tech_ece_internetThings Students
B_tech_ece_internetThings=data[data.MHRDName=="Bachelor of Technology in Electronics and Communication Engineering (Internet of Things)"]

#Bachelor of Technology in Computer Science and Engineering (Full Stack Web Developer)
B_tech_cse_fullStack_WbDev=data[data.MHRDName=="Bachelor of Technology in Computer Science and Engineering (Full Stack Web Developer)"]

#Bachelor of Technology in Computer Science and Engineering (Machine Learning)
B_tech_cse_machineLearning=data[data.MHRDName=="Bachelor of Technology in Computer Science and Engineering (Machine Learning)"]

#Bachelor of Technology in Computer Science and Engineering (Cloud Computing)
B_tech_cse_cloudComputing=data[data.MHRDName=="Bachelor of Technology in Computer Science and Engineering (Cloud Computing)"]

#B_tech_civil_students
B_tech_civil_students=data[data.MHRDName=="Bachelor of Technology (Civil Engineering)"]

#Bachelor of Technology in Mechanical Engineering (Robotics and Mechatronics)
B_tech_MeEn_robMachatronics=data[data.MHRDName=="Bachelor of Technology in Mechanical Engineering (Robotics and Mechatronics)"]

#Bachelor of Technology (Automobile Engineering)
B_tech_amEng=data[data.MHRDName=="Bachelor of Technology (Automobile Engineering)"]

#Bachelor of Technology (Biotechnology)
B_tech_biotechnology=data[data.MHRDName=="Bachelor of Technology (Biotechnology)"]

#Bachelor of Technology (Electronics and Communication Engineering)
B_tech_elec_comm=data[data.MHRDName=="Bachelor of Technology (Electronics and Communication Engineering)"]

#Bachelor of Technology (Biomedical Engineering)
B_tech_bioMedical_eng=data[data.MHRDName=="Bachelor of Technology (Biomedical Engineering)"]

#Bachelor of Technology (Electrical and Electronics Engineering)
B_tech_electrical_and_electronics=data[data.MHRDName=="Bachelor of Technology (Electrical and Electronics Engineering)"]

#Bachelor of Technology (Aerospace Engineering)
B_tech_aerospace=data[data.MHRDName=="Bachelor of Technology (Aerospace Engineering)"]

#Bachelor of Technology (Petroleum Engineering)
B_tech_petroleum=data[data.MHRDName=="Bachelor of Technology (Petroleum Engineering)"]

#Bachelor of Technology in Computer Science and Engineering (Big Data)
B_tech_cse_bigdata=data[data.MHRDName=="Bachelor of Technology in Computer Science and Engineering (Big Data)"]

#Bachelor of Technology (Chemical Engineering)
B_tech_chemical=data[data.MHRDName=="Bachelor of Technology (Chemical Engineering)"]

#Bachelor of Technology (Mechanical Engineering)
B_tech_MeEng=data[data.MHRDName=="Bachelor of Technology (Mechanical Engineering)"]

#Bachelor of Technology (Computer Science and Engineering)
B_tech_cse=data[data.MHRDName=="Bachelor of Technology (Computer Science and Engineering)"]

#Bachelor of Architecture
B_architecture=data[data.MHRDName=="Bachelor of Architecture"]

#Diploma in Computer Science Engineering students
D_cse_students=data[data.MHRDName=="Diploma in Computer Science Engineering"]

#Diploma in Mechanical Engineering
D_MeEn_students=data[data.MHRDName=="Diploma in Mechanical Engineering"]

#Diploma in Civil Engineering
D_civil_eng=data[data.MHRDName=="Diploma in Civil Engineering"]

#Diploma in Electrical Engineering
D_elec_eng=data[data.MHRDName=="Diploma in Electrical Engineering"]



#Integrated Bachelor of Technology - Master of Technology (Computer Science and Engineering)
I_Btech_Mtech_cse_students=data[data.MHRDName=="Integrated Bachelor of Technology - Master of Technology (Computer Science and Engineering)"]

#Integrated Bachelor of Technology - Master of Technology (Biotechnology)
I_Btech_Mtech_biotechnology=data[data.MHRDName=="Integrated Bachelor of Technology - Master of Technology (Biotechnology)"]

#Integrated Bachelor of Science - Master of Science (Microbiology)
I_BSc_MSc_microbiology=data[data.MHRDName=="Integrated Bachelor of Science - Master of Science (Microbiology)"]



#B.Sc_students(Agriculture)
B_Sc_agri_hon_students=data[data.MHRDName=="Bachelor of Science (Honours) (Agriculture)"]

#Bachelor of Science (Honours) (Chemistry )
B_Sc_hon_chem=data[data.MHRDName=="Bachelor of Science (Honours) (Chemistry )"]

#Bachelor of Science (Forensic Science)
B_Sc_forensicSc=data[data.MHRDName=="Bachelor of Science (Forensic Science)"]

#Bachelor of Science (Biotechnology)
B_Sc_biotechnology=data[data.MHRDName=="Bachelor of Science (Biotechnology)"]

#Bachelor of Science (Honours) (Physics)
B_Sc_hon_phy=data[data.MHRDName=="Bachelor of Science (Honours) (Physics)"]

#Bachelor of Computer Applications
B_comp_app=data[data.MHRDName=="Bachelor of Computer Applications"]



#Master of Technology (Food Technology)
M_tech_foodTech=data[data.MHRDName=="Master of Technology (Food Technology)"]

#Master of Technology (Construction Management)
M_tech_const_mngmnt=data[data.MHRDName=="Master of Technology (Construction Management)"]



#Master of Science (Information Technology)
M_Sc_IT=data[data.MHRDName=="Master of Science (Information Technology)"]

#Master of Science (Zoology)
M_Sc_zoology=data[data.MHRDName=="Master of Science (Zoology)"]


#processing.....
Total_BTech_Students=len(B_tech_cse_dataScience)+len(B_tech_cse_cyberSecurity)+len(B_tech_cse_androidDevelopment)+len(B_tech_ece_internetThings)+len(B_tech_cse_fullStack_WbDev)+len(B_tech_cse_machineLearning)+len(B_tech_cse_cloudComputing)+len(B_tech_civil_students)+len(B_tech_MeEn_robMachatronics)+len(B_tech_amEng)+len(B_tech_biotechnology)+len(B_tech_students)+len(B_tech_bioMedical_eng)+len(B_tech_electrical_and_electronics)+len(B_tech_aerospace)+len(B_tech_petroleum)+len(B_tech_cse_bigdata)+len(B_tech_chemical)+len(B_tech_elec_comm)+len(B_tech_MeEng)+len(B_tech_cse)
#print(Total_BTech_Students)

Total_Diploma_Students=len(D_cse_students)+len(D_MeEn_students)+len(D_civil_eng)+len(D_elec_eng)
#print(Total_Diploma_Students)

Total_BSc_Students=len(B_Sc_agri_hon_students)+len(B_Sc_hon_chem)+len(B_Sc_forensicSc)+len(B_Sc_biotechnology)+len(B_Sc_hon_phy)
#print(Total_BSc_Students)

Total_BCA_Students=len(B_comp_app)
#print(Total_BCA_Students)

Total_BArchitecture=len(B_architecture)
#print(Total_BArchitecture)

Total_MSc_Students=len(M_Sc_IT)+len(M_Sc_zoology)
#print(Total_MSc_Students)

Total_Mtech_Students=len(M_tech_const_mngmnt)+len(M_tech_foodTech)
#print(Total_Mtech_Students)

Total_Integrated_Btech_Mtech=len(I_Btech_Mtech_cse_students)+len(I_Btech_Mtech_biotechnology)
#print(Total_Integrated_Btech_Mtech)

Total_Integrated_BSc_MSc=len(I_BSc_MSc_microbiology)
#print(Total_Integrated_BSc_MSc)


print(Total_BTech_Students+Total_Diploma_Students+Total_BSc_Students+Total_BCA_Students+Total_BArchitecture+Total_MSc_Students+Total_Mtech_Students+Total_Integrated_Btech_Mtech+Total_Integrated_BSc_MSc)
# Out:
# 1267
# 1652

# %%
from random import sample
import matplotlib.colors as pltc
all_colors = [k for k,v in pltc.cnames.items()]

labels = 'B_tech_cse_dataScience','B_tech_cse_cyberSecurity','B_tech_cse_androidDevelopment','B_tech_ece_internetThings','B_tech_cse_fullStack_WbDev','B_tech_cse_machineLearning','B_tech_cse_cloudComputing','B_tech_civil_students','B_tech_MeEn_robMachatronics','B_tech_amEng','B_tech_biotechnology','B_tech_students','B_tech_bioMedical_eng','B_tech_electrical_and_electronics','B_tech_aerospace','B_tech_petroleum','B_tech_cse_bigdata','B_tech_chemical','B_tech_elec_comm','B_tech_MeEng','B_tech_cse'
sizes = [len(B_tech_cse_dataScience),len(B_tech_cse_cyberSecurity),len(B_tech_cse_androidDevelopment),len(B_tech_ece_internetThings),len(B_tech_cse_fullStack_WbDev),len(B_tech_cse_machineLearning),len(B_tech_cse_cloudComputing),len(B_tech_civil_students),len(B_tech_MeEn_robMachatronics),len(B_tech_amEng),len(B_tech_biotechnology),len(B_tech_students),len(B_tech_bioMedical_eng),len(B_tech_electrical_and_electronics),len(B_tech_aerospace),len(B_tech_petroleum),len(B_tech_cse_bigdata),len(B_tech_chemical),len(B_tech_elec_comm),len(B_tech_MeEng),len(B_tech_cse)]

# Plot
for val in range(2):
    colors = sample(all_colors, len(labels))
fig = plt.figure(figsize=(28,18))
fig.patch.set_facecolor('xkcd:mint green')
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%',shadow=True,startangle=120)
plt.legend(labels, loc="best",shadow=True)
plt.axis('equal')
plt.show()

# %%
T='This graph is made to show which department students is more in my dateset by what percentage'
labels = 'Total_BTech_Students','Total_Diploma_Students','Total_BSc_Students','Total_BCA_Students','Total_BArchitecture','Total_MSc_Students','Total_Mtech_Students','Total_Integrated_Btech_Mtech','Total_Integrated_BSc_MSc'
sizes = [Total_BTech_Students,Total_Diploma_Students,Total_BSc_Students,Total_BCA_Students,Total_BArchitecture,Total_MSc_Students,Total_Mtech_Students,Total_Integrated_Btech_Mtech,Total_Integrated_BSc_MSc]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0.1, 0.2, 0.1, 0.2, 0.3, 0.2, 0.1)  # explode 1st slice

# Plot
for val in range(2):
    colors = sample(all_colors, len(labels))
fig = plt.figure(figsize=(18,12))
fig.patch.set_facecolor('xkcd:mint green')
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=2)
plt.title(T,bbox={'facecolor':'0.8', 'pad':5})
plt.legend(labels, loc="center left",shadow=True)
plt.axis('equal')
plt.show()

# %%
T='This graph defines my assumption that most of students of B_Sc in my dataset belogs to Agriculture'
label='B_Sc_agri_hon_students','B_Sc_hon_chem','B_Sc_forensicSc','B_Sc_biotechnology','B_Sc_hon_phy'
size=[len(B_Sc_agri_hon_students),len(B_Sc_hon_chem),len(B_Sc_forensicSc),len(B_Sc_biotechnology),len(B_Sc_hon_phy)]
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
plt.pie(size,labels=label,autopct='%1.1f%%',startangle=45)
plt.title(T,bbox={'facecolor':'0.8', 'pad':5})
plt.legend(label,loc='lower left')

plt.show()

# %%
T='MY assumption ETT and ETP is important to get A+ Grade'
GradeAplus=B_tech_cse_dataScience[B_tech_cse_dataScience.Grade=="A+"]
ETT_Absent=GradeAplus.ETT_100.isna().sum()
ETP_Absent=GradeAplus.ETP_100.isna().sum()
len(GradeAplus)
labels='Students having A+','Students having A+ without giving ETT or ETP'
size=[len(GradeAplus),ETP_Absent+ETT_Absent]
plt.pie(size,labels=labels)
plt.title(T,bbox={'facecolor':'0.8', 'pad':5})
plt.show()
print(ETP_Absent+ETT_Absent)
print(GradeAplus[['Grade','ETT_100','ETP_100']])
# Out:
# 25
#      Grade  ETT_100  ETP_100
# 143     A+     75.0      NaN
# 145     A+      NaN     87.0
# 146     A+     78.0      NaN
# 151     A+     78.0      NaN
# 518     A+     82.0      NaN
# 519     A+      NaN     91.0
# 520     A+     79.0      NaN
# 524     A+     80.0      NaN
# 525     A+     75.0      NaN
# 635     A+      NaN     91.0
# 890     A+     62.0      NaN
# 892     A+     78.0      NaN
# 894     A+     75.0      NaN
# 1140    A+      NaN     93.0
# 1142    A+     79.0      NaN
# 1143    A+      NaN     88.0
# 1144    A+     63.0      NaN
# 1145    A+     76.0      NaN
# 1504    A+     79.0      NaN
# 1506    A+      NaN     85.0
# 1511    A+     68.0      NaN
# 1512    A+     65.0      NaN
# 1586    A+     93.0      NaN
# 1588    A+     75.0      NaN
# 1590    A+     79.0      NaN
